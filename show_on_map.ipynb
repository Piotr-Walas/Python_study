# %%
pip install folium
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import os
import json 
import folium 
import datetime as dt 
import sys

path = os.listdir(path = "C:/Users/piowa/Desktop/IOB/rowery")

files = []

for t in path:
    x = dt.datetime(int(t[0:4]), int(t[4:6]), int(t[6:8]), int(t[9:11]), int(t[11:13]), int(t[13:15]))
    files.append((x, t))

files = sorted(files)
print(files)
# Out:
# [(datetime.datetime(2018, 3, 4, 0, 0, 20), '20180304_000020.json'), (datetime.datetime(2018, 3, 4, 0, 10, 19), '20180304_001019.json'), (datetime.datetime(2018, 3, 4, 0, 20, 25), '20180304_002025.json'), (datetime.datetime(2018, 3, 4, 0, 40, 16), '20180304_004016.json'), (datetime.datetime(2018, 3, 4, 0, 50, 25), '20180304_005025.json'), (datetime.datetime(2018, 3, 4, 1, 0, 18), '20180304_010018.json'), (datetime.datetime(2018, 3, 4, 1, 10, 16), '20180304_011016.json'), (datetime.datetime(2018, 3, 4, 1, 20, 16), '20180304_012016.json'), (datetime.datetime(2018, 3, 4, 1, 30, 17), '20180304_013017.json'), (datetime.datetime(2018, 3, 4, 1, 40, 16), '20180304_014016.json'), (datetime.datetime(2018, 3, 4, 1, 50, 24), '20180304_015024.json'), (datetime.datetime(2018, 3, 4, 2, 0, 17), '20180304_020017.json'), (datetime.datetime(2018, 3, 4, 2, 10, 18), '20180304_021018.json'), (datetime.datetime(2018, 3, 4, 2, 20, 17), '20180304_022017.json'), (datetime.datetime(2018, 3, 4, 2, 30, 17), '2018
# ...

# %%
with open("C:/Users/piowa/Desktop/IOB/rowery/20180304_001019.json") as bicycles:
        data = json.load(bicycles)

# %%
stations = data[0]["places"]
Frame = pd.DataFrame(stations)
Frame
# Out:
#          uid              lat              lng  \
# 0    2585259        52.296298       20.9583575
# 1    2585263       52.2909738       20.9295559
# 2    2585265       52.2901732       20.9503698
# 3    2585267        52.285914        20.940561
# 4    2585269       52.2336142       21.0146353
# ..       ...              ...              ...
# 344  2681672       52.2414927       20.9292126
# 345  2681674  52.180211511505  21.002726554871
# 346  3616030  52.298441118793  21.024162769318
# 347  4313700        52.320309        21.008012
# 348  4313707        52.182668        20.998239
#
#                                     name spot number bikes bike_racks  \
# 0                        Dewajtis - UKSW    1   9402    25         30
# 1                          Metro Młociny    1   9403    19         30
# 2                  Marymoncka - Dewajtis    1   9404    24         30
# 3                       Metro Wawrzyszew    1   9405    14         20
# ...

# %%
def
